# %%
import pandas as pd

# %%
df=pd.read_csv("adult.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 4       18                 ?  103497  Some-college               10
# 5       34           Private  198693          10th                6
# 6       29                 ?  227026       HS-grad                9
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 8       24           Private  369667  Some-college               10
# 9       55           Private  104996       7th-8th                4
# 10      65           Private  184454       HS-grad                9
# 11      36       Federal-gov  212465     Bachelors               13
# 12      26           Private   82091       HS-grad                9
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    age  workclass  fnlwgt   education  educational-num      marital-status  \
# 0   25    Private  226802        11th                7       Never-married
# 1   38    Private   89814     HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951  Assoc-acdm               12  Married-civ-spouse
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
# 1    Farming-fishing      Husband  White   Male             0             0
# 2    Protective-serv      Husband  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K

# %%
df.tail(3)
# Out:
#        age     workclass  fnlwgt education  educational-num  \
# 48839   58       Private  151910   HS-grad                9
# 48840   22       Private  201490   HS-grad                9
# 48841   52  Self-emp-inc  287927   HS-grad                9
#
#            marital-status       occupation relationship   race  gender  \
# 48839             Widowed     Adm-clerical    Unmarried  White  Female
# 48840       Never-married     Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse  Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K

# %%
type(df.age)
# Out:
# pandas.core.series.Series

# %%
df['age']
# Out:
# 0        25
# 1        38
# 2        28
# 3        44
# 4        18
# 5        34
# 6        29
# 7        63
# 8        24
# 9        55
# 10       65
# 11       36
# 12       26
# 13       58
# 14       48
# 15       43
# 16       20
# 17       43
# 18       37
# 19       40
# 20       34
# 21       34
# 22       72
# 23       25
# 24       25
# 25       45
# 26       22
# 27       23
# 28       54
# 29       32
#          ..
# 48812    30
# 48813    34
# 48814    54
# 48815    37
# 48816    22
# 48817    34
# 48818    30
# 48819    38
# 48820    71
# 48821    45
# 48822    41
# 48823    72
# 48824    45
# 48825    31
# 48826    39
# 48827    37
# 48828    43
# 48829    65
# 48830    43
# 48831    43
# 48832    32
# 48833    43
# 48834    32
# 48835    53
# 48836    22
# 48837    27
# 48838    40
# 48839    58
# 48840    22
# 48841    52
# Name: age, Length: 48842, dtype: int64

# %%
df[['age','education']]
# Out:
#        age     education
# 0       25          11th
# 1       38       HS-grad
# 2       28    Assoc-acdm
# 3       44  Some-college
# 4       18  Some-college
# 5       34          10th
# 6       29       HS-grad
# 7       63   Prof-school
# 8       24  Some-college
# 9       55       7th-8th
# 10      65       HS-grad
# 11      36     Bachelors
# 12      26       HS-grad
# 13      58       HS-grad
# 14      48       HS-grad
# 15      43       Masters
# 16      20  Some-college
# 17      43       HS-grad
# 18      37       HS-grad
# 19      40     Doctorate
# 20      34     Bachelors
# 21      34  Some-college
# 22      72       7th-8th
# 23      25     Bachelors
# 24      25     Bachelors
# 25      45       HS-grad
# 26      22       HS-grad
# 27      23       HS-grad
# 28      54       HS-grad
# 29      32  Some-college
# ...    ...           ...
# 48812   30     Bachelors
# 48813   34     Doctorate
# 48814   54     Bachelors
# 48815   37  Some-college
# 48816   22          12th
# ...

# %%
df[['relationship','race','gender']][df['age']>50]
# Out:
#         relationship                race  gender
# 7            Husband               White    Male
# 9            Husband               White    Male
# 10           Husband               White    Male
# 13           Husband               White    Male
# 22     Not-in-family               White  Female
# 28           Husband               White    Male
# 31         Unmarried               White  Female
# 35           Husband               White    Male
# 40           Husband               White    Male
# 47           Husband               White    Male
# 48     Not-in-family               Black  Female
# 49     Not-in-family               White  Female
# 56           Husband               White    Male
# 70           Husband               White    Male
# 77           Husband               White    Male
# 87           Husband               White    Male
# 90     Not-in-family               White  Female
# 93     Not-in-family               White    Male
# ...

# %%
df['age'].max()
# Out:
# 90

# %%
df[['relationship','race','gender']][df['age']==df['age'].max()]
# Out:
#          relationship                race  gender
# 899           Husband               White    Male
# 3496    Not-in-family               White    Male
# 6976          Husband               White    Male
# 7414    Not-in-family               White    Male
# 7419          Husband               White    Male
# 8427    Not-in-family               White    Male
# 8982          Husband  Asian-Pac-Islander    Male
# 10735       Own-child               White    Male
# 11871   Not-in-family               White  Female
# 12446       Own-child               White  Female
# 13958       Own-child               White    Male
# 15088   Not-in-family               White  Female
# 16503   Not-in-family               Black    Male
# 17321   Not-in-family               White  Female
# 18216         Husband               White    Male
# 18584   Not-in-family  Asian-Pac-Islander    Male
# 19172       Own-child               White  Female
# 20351       Own-child               White    Male
# ...
